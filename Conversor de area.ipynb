# %%
Convertir_area_a_unidades
#crear un diccionario vacío
áreaD = {}

areaD['Pie cuadrado']      = 0.09290304
areaD['Vara cuadrara']     = 0,698896
areaD['Yarda cuadrada']    = 8.361,2736
areaD['Metro cuadrado']    = 1.0
areaD['Manzanas  ']        = 6988,96
areaD['Hectarea']          = 6988,96

def convertArea(x, unit1, unit2):
    
    if (unit1 in areaD) and (unit2 in areaD):
        factor1 = areaD[unit1]
        factor2 = areaD[unit2]
        return factor2*x/factor1
    else:
        return False
unit1 = ''
unit2 = ''
outcome = convertArea(x, unit1, unit2)
if outcome is not False:
    print "1)  %f %s = %f %s" % (x, unit1, outcome, unit2)
else:
    print "1)    % (unit1, unit2)


unit2 = ''  
outcome = convertArea(x, unit1, unit2)
if outcome is not False:
    print "2)  %f %s = %f %s" % (x, unit1, outcome, unit2)
else:
    print "2)
# Out:
#   File "<ipython-input-3-476a29a662d2>", line 24
#     print "1)  %f %s = %f %s" % (x, unit1, outcome, unit2)
#                             ^
# SyntaxError: invalid syntax
